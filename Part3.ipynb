# %% [markdown]
# The restaurant menu consists of a selection of pizzas, but this prototype application focuses on letting a customer order their own pizza (£12.99), selecting 2 out of the following toppings:
#
# -	Mozzarella
# -	Pepperoni
# -	Ham
# -	Pineapple
# -	Olives
#
# Besides pizzas, the customer can also order a portion of garlic bread (£4.99) and also a drink (£2.99) - various drinks are available but the customer will help themselves to these via a self-service machine (so the app should just display ‘Drink’ or ‘Beverage’ rather than specific drinks).

# %%
import re

class Pizza:
    def __init__(self, productName, topping1, topping2, price):
        self.productName =  productName
        self.topping1 = topping1
        self.topping2 = topping2
        self.sauce = sauce
        self.price = price

class GarlicBread:
    def __init__(self, price):
        self.price = price

class Drink:
    def __init__(self, price):
        self.price = price

# %%
def queryUserinput(): ## Define the run function
    while True: 
        chosenItem = input("Welcome to Uncle Enzo's Pizza!\nPlease select whether you would like to order, or to checkout:\nA - Pizza\nB - Garlic Bread\nC - Drink\nD - Checkout\nPlease select an option using the characters A, B, C or D, and order one at a time:").strip().upper()

        if chosenItem not in ("A", "B", "C", "D"):
            print("Please select a valid option: A, B, C or D")
        else:
            return chosenItem

# %%
choice = queryUserinput()

if choice == "A":
    userToppings = input("Please select what topping you would like:\nA - Pepperoni\nB - Chicken\nC - Olives\nD - Burrata\nE - Halal Pepperoni\nIf more than one topping, please split each up with a comma.").strip()
    toppingsList = re.split(",", userToppings) ## Create a list of the user Toppings
    print(toppingsList)
    for index in range(len(toppingsList)):
        if toppingsList[index] == "A":
            toppingsList[index] = "Pepperoni"
        elif toppingsList[index] == "B":
            toppingsList[index] = "Chicken"
        else:
            pass
    print(toppingsList)
else:
    print("Hi")
# Out:
#   Cell In[55], line 12
#     else pass
#          ^
# SyntaxError: expected ':'
