# %% [markdown]
# Part 1 - Task 1
#
# Create a new variable for each of the data types below, assigning a suitable value to each variable.  Print the variables out, checking they work.
#
# •	String
# •	Float
# •	Int
# •	Date
# •	Bool
# •	Dictionary
# •	List

# %%
def dataTypeCheck(variable): ## Creating a testing function to check the data type of variable for efficiency purposes 
                             ## rather than making a new function for each task and variable
    print(f"{variable} is a {type(variable)}") ## Writing a print line to return variable data type - could have used return here
                                                ## but would have had to below said print(dataTypeCheck(firstName)

# Example to check the function works:
firstName = "Owen" ## Creating a string variable for my name
dataTypeCheck(firstName)  # Output: Alice is a <class 'str'> so I'm confident it will work
# Out:
# Owen is a <class 'str'>

# %%
from datetime import date

firstName = "Owen"
ageInYears = 20
heightInFeet = 6.1
dateOfBirth = date(2005, 9, 7)
livesInLetchworth = True
pet = {"name": "bella",
        "breed": "Staffordshire Bull Terrier",
        "age": "3",
        "favourite treat": "Dentastix"}
familyMemberNames = ["Annie", "Graham", "Andrew", "Natasha"]

# %% [markdown]
# Using the variables you created (see above):
# Write code expressions to perform the operations described below, creating new variables to store the result where required.
# i)	 Divide an integer by a float, displaying the answer as part of a string output.
# ii)	 Multiply a string by an integer.
# iii) Replace the first and final elements of a list with two new values.

# %%
## i) We are using the integer (ageInYears) divided by the float (heightInFeet):

ageDividedByHeight = ageInYears / heightInFeet # Creating the output variable

print(f"This is the output: {ageDividedByHeight}") ## Printing the output ageDividedByHeight to check
print(f"This is the datatype: {type(ageDividedByHeight)}") ## Printing the datatype of ageDividedByHeight to check

stringOutput = f"This is the result of my age divided by my height as a string: {ageDividedByHeight}" ## Creating the string output 
                                                                                          ## of the ageDividedByHeight

print(stringOutput) ## Printing the string output stringOutput
print(f"This is the datatype: {type(stringOutput)}") ## Printing the datatype of stringOutput
# Out:
# This is the output: 3.278688524590164
# This is the datatype: <class 'float'>
# This is the result of my age divided by my height as a string: 3.278688524590164
# This is the datatype: <class 'str'>

# %%
## ii) Multiplying a string by an integer; we are using the string (firstName) and multiplying it by an integer

multipliedString = firstName * 3 ## Creating a new variable to store our multiplied string (multipliedString)
print(multipliedString) ## Print the output multipliedString
# Out:
# OwenOwenOwen

# %%
## iii) Replacing the first and last elements of our list (familyMemberNames)

print(familyMemberNames) ## Check the original list before updates

newFamilyMemberNames = familyMemberNames.copy() ## Use .copy() to create a copy of the original list
newFamilyMemberNames[0] = "Bella" ## Updating the first (0 based index means 0th item within the list)
newFamilyMemberNames[-1] = "Beau" ## Updating the final (0 based index means -1th item within the list)

print(newFamilyMemberNames) ## Printing the new, updated list

if newFamilyMemberNames == ['Annie', 'Graham', 'Andrew', 'Natasha']: ## check if the list is not updated
    print("Please try Run All on the python notebook to update the list, or investigate the code.") ## Error checks in terminal
else: 
    pass ## If nothing is wrong then pass

print("The first list is the list before any updates, the second list is the updated one. If there were any discrepancies an error message would appear.")
# Out:
# ['Annie', 'Graham', 'Andrew', 'Natasha']
# ['Bella', 'Graham', 'Andrew', 'Beau']
# The first list is the list before any updates, the second list is the updated one. If there were any discrepancies an error message would appear.

# %% [markdown]
# Write conditional statements to address the following criteria.  You should again include suitable code to display and test all outcomes of your statements.
#
# i)	Using your integer variable from task 1, write a statement that prints “this number is even” or “this number is odd”, depending on the value stored in your variable.
# ii)	Using a different statement, identify if the date variable you defined in task 1 occurs either before 1st January 2000, between 1st January 2000 and 31st December 2009, or after 31st December 2009.
# iii)	Examine your code for task 1B.  Write a conditional statement of your choice that tests the result of one of your code expressions.

# %%
## iterate through a dictionary and double each value, then add this to a list
dict = {"first": "one", 
"second": "two", 
"third":"three"}
list = []

print(dict)

for value in dict:
    value = dict[value] * 2
    list.append(value)

print(list)
# Out:
# {'first': 'one', 'second': 'two', 'third': 'three'}
# ['oneone', 'twotwo', 'threethree']
