# %% [markdown]
# Part 1 - Task

# %%
def dataTypeCheck(variable): ## Creating a testing function to check the data type of variable
    print(f"{variable} is a {type(variable)}") ## Writing a print line to return variable data type - could have used return here
                                                ## but would have had to below said print(dataTypeCheck(firstName)
# Example to check the function works:
dataTypeCheck(firstName)  # Output: Alice is a <class 'str'> so I'm confident it will work
# Out:
# Alice is a <class 'str'>

# %%
from datetime import date

firstName = "Owen"
age = 20
heightInFeet = 6.1
dateOfBirth = date(2005, 9, 7)
isBPPStudent = True
pet = {"name": "bella",
        "breed": "Staffordshire Bull Terrier",
        "age": "3",
        "favourite treat": }

# %%
def dataTypeCheck(variable): 
    
    print(f"{variable} is a {type(variable)}!") ## Only writing check for string type

# Example:
dataTypeCheck(firstName)  # Output: Alice is a string!
# Out:
# Alice is a <class 'str'>!
